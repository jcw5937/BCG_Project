# %% [markdown]
# # Exploratory Data Analysis
#
# ## Import packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ---
#
# ## Loading data with Pandas
#
# Load `client_data.csv` and `price_data.csv` into individual dataframes

# %%
client_df = pd.read_csv('./Data/client_data.csv')
price_df = pd.read_csv('./Data/price_data.csv')

# %%
client_df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %% [markdown]
# ---
#
# ## Descriptive statistics of data
#
# ### Data types

# %%
client_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  str
#  1   channel_sales                   14606 non-null  str
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  str
#  6   date_end                        14606 non-null  str
#  7   date_modif_prod                 14606 non-null  str
#  8   date_renewal                    14606 non-null  str
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  str
#  1   price_date          193002 non-null  str
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), str(2)
# memory usage: 11.8 MB

# %% [markdown]
# ### Statistics

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
client_df.nunique()
# Out:
# id                                14606
# channel_sales                         8
# cons_12m                          11065
# cons_gas_12m                       2112
# cons_last_month                    4751
# date_activ                         1796
# date_end                            368
# date_modif_prod                    2129
# date_renewal                        386
# forecast_cons_12m                 13993
# forecast_cons_year                 4218
# forecast_discount_energy             12
# forecast_meter_rent_12m            3528
# forecast_price_energy_off_peak      516
# forecast_price_energy_peak          329
# forecast_price_pow_off_peak          41
# has_gas                               2
# imp_cons                           7752
# margin_gross_pow_ele               2391
# margin_net_pow_ele                 2391
# nb_prod_act                          10
# net_margin                        11965
# num_years_antig                      13
# ...

# %%
price_df.nunique()
# Out:
# id                    16096
# price_date               12
# price_off_peak_var     1853
# price_peak_var         1189
# price_mid_peak_var      711
# price_off_peak_fix       66
# price_peak_fix           31
# price_mid_peak_fix       28
# dtype: int64

# %% [markdown]
# ---
#
# ## Data visualization

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# Thhe first function `plot_stacked_bars` is used to plot a stacked bar chart. An example of how you could use this is shown below:

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn'] # rename columns
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# The second function `annotate_bars` is used by the first function, but the third function `plot_distribution` helps you to plot the distribution of a numeric column. An example of how it can be used is given below:

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_12m', axs)

# %% [markdown]
# ---
#
# ## Client Data EDA

# %% [markdown]
# `Research question 1:` If a customer is subscribed to more active products and services, are they less likely to churn?

# %%
products = client_df[['id', 'nb_prod_act', 'churn']]
fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(products, 'nb_prod_act', axs)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# It looks like there is not a correlation between number of active products and churn rate.

# %% [markdown]
# `Research question 2:` Are longer or shorter contracts more likely to churn?

# %%
contracts = client_df[['id', 'date_activ', 'date_end', 'churn']]
contracts['date_activ'] = pd.to_datetime(contracts['date_activ'])
contracts['date_end'] = pd.to_datetime(contracts['date_end'])

#print(contracts['date_activ'].dtype)
#print(contracts['date_end'].dtype)

contracts['contract_length'] = (contracts['date_end'] - contracts['date_activ']).dt.days

# %%
fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(contracts[['id', 'contract_length', 'churn']], 'contract_length', axs)

# %% [markdown]
# It looks like there are many specific contract lengths that have lots of customers, suggesting contracts are often set to standard durations. I want to take a closer look at the common contract lengths and see if any have a higher churning rate.

# %%
top_lengths = contracts['contract_length'].value_counts().head(5).reset_index()
top_lengths.columns = ['contract_length', 'count']
top_lengths['years'] = top_lengths['contract_length'] / 365
top_lengths
# Out:
#    contract_length  count     years
# 0             1461   2451  4.002740
# 1             2557   2401  7.005479
# 2             2192   2203  6.005479
# 3             1827   2069  5.005479
# 4             1096    645  3.002740

# %%
spike_lengths = top_lengths['contract_length']

churn_by_length = contracts[contracts['contract_length'].isin(spike_lengths)].groupby('contract_length')['churn'].mean() * 100

fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(contracts[contracts['contract_length'].isin(spike_lengths)][['id', 'contract_length', 'churn']], 'contract_length', axs, bins_=5)

top_lengths_sorted = top_lengths.sort_values('contract_length')
labels = (top_lengths_sorted['contract_length'] / 365).round(0).astype(int).astype(str) + ' yrs'
axs.set_xticks(top_lengths_sorted['contract_length'])
axs.set_xticklabels(labels)
# Out:
# [Text(1096, 0, '3 yrs'),
#  Text(1461, 0, '4 yrs'),
#  Text(1827, 0, '5 yrs'),
#  Text(2192, 0, '6 yrs'),
#  Text(2557, 0, '7 yrs')]

# %% [markdown]
# It looks there even in the spikes of ending contracts, there is not a difference in churn rate.

# %% [markdown]
# `Research question 3:` Do customers with higher forecasted peak vs. off-peak price differences churn more? Are costumers price sensitive?

# %%
price_diff = client_df[['id', 'forecast_price_energy_peak', 'forecast_price_energy_off_peak', 'churn']].copy()
price_diff['peak_offpeak_diff'] = price_diff['forecast_price_energy_peak'] - price_diff['forecast_price_energy_off_peak']

fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(price_diff[['id', 'peak_offpeak_diff', 'churn']], 'peak_offpeak_diff', axs)

# %% [markdown]
# Looking at the chart, churn appears consistent across all price difference groups. Customers don't seem to be leaving at higher rates when the gap between peak and off-peak pricing is larger. This suggests the product may be relatively inelastic, meaning price differences alone are unlikely to be the primary driver of churning behavior.

# %% [markdown]
# `Researach question 4:` Are customers who subscribe to both gas and electricity services less likely to churn than electricity-only customers?

# %%
gas = client_df[['id', 'has_gas', 'churn']].copy()
gas['has_gas'] = gas['has_gas'].map({'t': 1, 'f': 0})

fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(gas, 'has_gas', axs, bins_=2)
# Out:
# has_gas
# 0    10.054371
# 1     8.185590
# Name: churn, dtype: float64

# %% [markdown]
# Customers without gas (0) make up the large majority of the dataset and show a noticeably higher churn rate compared to customers who have both gas and electricity (1). This suggests that customers with multiple services are more loyal and less likely to leave, possibly because switching providers becomes more complicated when multiple services are bundled together.

# %% [markdown]
# `Research question 5:` Do customers who experienced increasing energy prices in the months leading up to their contract end churn at a higher rate?

# %%
price_df['price_date'] = pd.to_datetime(price_df['price_date'])
price_trends = price_df.groupby('id')[['price_off_peak_var', 'price_peak_var']].mean().reset_index()
price_trends = price_trends.merge(client_df[['id', 'churn']], on='id')

fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(price_trends[['id', 'price_peak_var', 'churn']], 'price_peak_var', axs)

# %% [markdown]
# The cluster around 0.10 is smaller in volume but shows a noticeably higher churn proportion, particularly the bar just above 0.10 where the orange churn segment is quite large relative to the blue. This suggests that customers paying higher variable peak prices are more likely to churn, which supports the idea that peak pricing is a meaningful driver of customer attrition.

# %% [markdown]
# `Research question 6:` Are customers on higher fixed price plans more likely to churn than those on higher variable price plans?

# %%
price_type = price_df.groupby('id')[['price_off_peak_var', 'price_off_peak_fix']].mean().reset_index()
price_type = price_type.merge(client_df[['id', 'churn']], on='id')
price_type['fix_var_diff'] = price_type['price_off_peak_fix'] - price_type['price_off_peak_var']

fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
plot_distribution(price_type[['id', 'fix_var_diff', 'churn']], 'fix_var_diff', axs)

# %% [markdown]
# Churn appears proportionally similar across both clusters, suggesting that the difference between fixed and variable pricing doesn't strongly influence whether a customer churns or not.
